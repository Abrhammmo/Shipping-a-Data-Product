# %% [markdown]
# ## Task-2

# %% [markdown]
# ### Data Modeling and Transformation

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join('..')))

from scripts.load_raw_to_postgres import run_loader

result = run_loader()

print(result)
